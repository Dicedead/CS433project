# %%
import random

import pandas as pd

from jsontodf import *
from scipy import stats
import seaborn as sns

# %% [markdown]
# ## Data exploration and analysis
# This notebook aims to test some basic aspects of the data as well as test the pipeline parsing to ``Dataframe``. First, a few sanity checks:

# %%
test_emissions_df, test_no_emissions_df = jsontodf("../json_data/json_misc/compressed_test_json.json", two_returns=True)

# %%
test_emissions_df
# Out:
#    x_p    y_p    z_p  dx_p  dy_p  dz_p  en_p  dist_p      de_p    cos_p  \
# 0  0.0  100.0  100.0   0.1   0.0   0.0   0.0   206.0  0.000543  0.82945
#
#      x_c    y_c    z_c   dx_c   dy_c   dz_c      en_c
# 0  206.0  100.0  100.0  0.121  0.973  0.195  0.000553

# %%
test_no_emissions_df
# Out:
# Empty DataFrame
# Columns: [x_p, y_p, z_p, dx_p, dy_p, dz_p, en_p, dist_p, de_p, cos_p]
# Index: []

# %%
test_events_df = jsontodf("../json_data/json_misc/compressed_test_json.json", two_returns=False)

# %%
test_events_df
# Out:
#    x_p    y_p    z_p  dx_p  dy_p  dz_p  en_p  dist_p      de_p    cos_p  \
# 0  0.0  100.0  100.0   0.1   0.0   0.0   0.0   206.0  0.000543  0.82945
#
#    emission    x_c    y_c    z_c   dx_c   dy_c   dz_c      en_c
# 0         1  206.0  100.0  100.0  0.121  0.973  0.195  0.000553

# %% [markdown]
# ### Time for the real deal
# Now let's study a few aspects of one of the given data describing interactions in the lung!

# %%
# %%time
lung_df = pd.read_pickle("../pickled_data/lung_dataset.pkl")
# Out:
# CPU times: total: 656 ms
# Wall time: 7.52 s

# %%
lung_df.head(50)
# Out:
#     x_p    y_p    z_p  dx_p  dy_p  dz_p  en_p   dist_p      de_p     cos_p  \
# 0   0.0  100.0  100.0   1.0   0.0   0.0   0.1   206.00  0.000543  0.829450
# 1   0.0  100.0  100.0   1.0   0.0   0.0   0.1   791.00  0.000014 -0.960107
# 2   0.0  100.0  100.0   1.0   0.0   0.0   0.1   800.00  0.000042  0.539941
# 3   0.0  100.0  100.0   1.0   0.0   0.0   0.1   570.00  0.000014 -0.984238
# 4   0.0  100.0  100.0   1.0   0.0   0.0   0.1    38.30  0.000014  0.931009
# 5   0.0  100.0  100.0   1.0   0.0   0.0   0.1   607.00  0.000042 -0.555998
# 6   0.0  100.0  100.0   1.0   0.0   0.0   0.1   283.00  0.000042  0.824379
# 7   0.0  100.0  100.0   1.0   0.0   0.0   0.1   510.00  0.000017 -0.382179
# 8   0.0  100.0  100.0   1.0   0.0   0.0   0.1   133.00  0.000014 -0.226209
# 9   0.0  100.0  100.0   1.0   0.0   0.0   0.1     7.66  0.000029 -0.796440
# 10  0.0  100.0  100.0   1.0   0.0   0.0   0.1   140.00  0.000029  0.803853
# 11  0.0  100.0  100.0   1.0   0.0   0.0   0.1    27.70  0.000029  0.999476
# 12  0.0  100.0  100.0   1.0   0.0   0.0   0.1   286.00  0.000042 -0.413040
# 13  0.0  100.0  100.0   1.0   0.0   0.0   0.1    85.70  0.000014  0.992584
# 14  0.0  100.0  100.0   1.0   0.0   0.0   0.1   832.00  0.000029  0.958423
# 15  0.0  100.0  100.0   1.0   0.0   0.0   0.1   373.00  0.000014  0.593597
# 16  0.0  100.0  100.0   1.0   0.0   0.0   0.1    86.90  0.000543 -0.993177
# 17  0.0  100.0  100.0   1.0   0.0   0.0   0.1   307.00  0.000014  0.205061
# 18  0.0  100.0  100.0   1.0   0.0   0.0   0.1    41.40  0.000042  0.352865
# 19  0.0  100.0  100.0   1.0   0.0   0.0   0.1   466.00  0.000014  0.730191
# 20  0.0  100.0  100.0   1.0   0.0   0.0   0.1   524.00  0.000037  0.934350
# 21  0.0  100.0  100.0   1.0   0.0   0.0   0.1   134.00  0.000014  0.956151
# 22  0.0  100.0  100.0   1.0   0.0   0.0   0.1   119.00  0.000015  0.237243
# 23  0.0  100.0  100.0   1.0   0.0   0.0   0.1   136.00  0.000537  1.000000
# 24  0.0  100.0  100.0   1.0   0.0   0.0   0.1    68.90  0.000029  0.087623
# 25  0.0  100.0  100.0   1.0   0.0   0.0   0.1    14.00  0.000014 -0.930907
# 26  0.0  100.0  100.0   1.0   0.0   0.0   0.1   818.00  0.000017  0.539350
# 27  0.0  100.0  100.0   1.0   0.0   0.0   0.1   119.00  0.000014  0.887426
# 28  0.0  100.0  100.0   1.0   0.0   0.0   0.1   301.00  0.000014 -0.995882
# 29  0.0  100.0  100.0   1.0   0.0   0.0   0.1   613.00  0.000014 -0.429389
# 30  0.0  100.0  100.0   1.0   0.0   0.0   0.1   174.00  0.000543 -0.451670
# 31  0.0  100.0  100.0   1.0   0.0   0.0   0.1   330.00  0.000014 -0.707306
# 32  0.0  100.0  100.0   1.0   0.0   0.0   0.1    96.60  0.000014 -0.707065
# 33  0.0  100.0  100.0   1.0   0.0   0.0   0.1   136.00  0.000029  0.720254
# 34  0.0  100.0  100.0   1.0   0.0   0.0   0.1   235.00  0.000014  0.622479
# 35  0.0  100.0  100.0   1.0   0.0   0.0   0.1   483.00  0.000288 -0.176998
# 36  0.0  100.0  100.0   1.0   0.0   0.0   0.1    18.00  0.000029  0.726496
# 37  0.0  100.0  100.0   1.0   0.0   0.0   0.1   153.00  0.000029 -0.590517
# 38  0.0  100.0  100.0   1.0   0.0   0.0   0.1   258.00  0.000029  0.766623
# 39  0.0  100.0  100.0   1.0   0.0   0.0   0.1    33.10  0.000543  0.607238
# 40  0.0  100.0  100.0   1.0   0.0   0.0   0.1   630.00  0.000042 -0.414787
# 41  0.0  100.0  100.0   1.0   0.0   0.0   0.1   558.00  0.000029  0.043176
# 42  0.0  100.0  100.0   1.0   0.0   0.0   0.1    99.10  0.000014  0.937854
# 43  0.0  100.0  100.0   1.0   0.0   0.0   0.1   330.00  0.000029  0.942413
# 44  0.0  100.0  100.0   1.0   0.0   0.0   0.1   530.00  0.000014  0.506272
# 45  0.0  100.0  100.0   1.0   0.0   0.0   0.1   656.00  0.000014  0.445724
# 46  0.0  100.0  100.0   1.0   0.0   0.0   0.1   403.00  0.000014  0.674115
# 47  0.0  100.0  100.0   1.0   0.0   0.0   0.1  1000.00  0.000000  1.000000
# 48  0.0  100.0  100.0   1.0   0.0   0.0   0.1    13.20  0.000014  0.576646
# 49  0.0  100.0  100.0   1.0   0.0   0.0   0.1   953.00  0.000014  0.026703
#
#     emission     x_c    y_c    z_c   dx_c    dy_c    dz_c      en_c
# 0          1  206.00  100.0  100.0  0.121  0.9730  0.1950  0.000553
# 1          1  791.00  100.0  100.0  0.987 -0.0925 -0.1280  0.027100
# 2          1  800.00  100.0  100.0  0.548  0.6300  0.5510  0.008040
# 3          1  570.00  100.0  100.0  0.906  0.0289  0.4220  0.022600
# 4          1   38.30  100.0  100.0  0.325 -0.4870  0.8110  0.002180
# 5          1  607.00  100.0  100.0  0.900 -0.2310  0.3690  0.021800
# 6          1  283.00  100.0  100.0  0.420  0.4370  0.7950  0.004630
# 7          1  510.00  100.0  100.0  0.885  0.4190 -0.2020  0.022400
# 8          1  133.00  100.0  100.0  0.859  0.5110 -0.0201  0.020300
# 9          1    7.66  100.0  100.0  0.979 -0.2020 -0.0190  0.026500
# 10         1  140.00  100.0  100.0  0.471 -0.4290  0.7710  0.005860
# 11         1   27.70  100.0  100.0  0.335 -0.0144 -0.9420  0.003220
# 12         1  286.00  100.0  100.0  0.914 -0.3960  0.0850  0.022900
# 13         1   85.70  100.0  100.0  0.305 -0.1570 -0.9390  0.002090
# 14         1  832.00  100.0  100.0  0.391 -0.2500 -0.8860  0.004380
# 15         1  373.00  100.0  100.0  0.489  0.7490  0.4470  0.006380
# 16         1   86.90  100.0  100.0  0.983  0.0365 -0.1820  0.025500
# 17         1  307.00  100.0  100.0  0.691 -0.5810 -0.4290  0.012700
# 18         1   41.40  100.0  100.0  0.583 -0.7470  0.3180  0.010800
# 19         1  466.00  100.0  100.0  0.429 -0.6110  0.6650  0.004810
# 20         1  524.00  100.0  100.0  0.326 -0.4990  0.8030  0.001840
# 21         1  134.00  100.0  100.0  0.496 -0.2010 -0.8450  0.006780
# 22         1  119.00  100.0  100.0  0.679  0.6910 -0.2460  0.013600
# 23         1  136.00  100.0  100.0  0.457  0.0243  0.8890  0.099500
# 24         1   68.90  100.0  100.0  0.744 -0.5640  0.3590  0.014100
# 25         1   14.00  100.0  100.0  0.890  0.0893 -0.4460  0.023300
# 26         1  818.00  100.0  100.0  0.500 -0.7680  0.3990  0.006570
# 27         1  119.00  100.0  100.0  0.455 -0.3580 -0.8150  0.005100
# 28         1  301.00  100.0  100.0  0.998 -0.0172 -0.0619  0.027600
# 29         1  613.00  100.0  100.0  0.885 -0.3750  0.2750  0.022400
# 30         1  174.00  100.0  100.0  0.881  0.3640  0.3030  0.021100
# 31         1  330.00  100.0  100.0  0.926 -0.2170 -0.3100  0.024100
# 32         1   96.60  100.0  100.0  0.954 -0.2480 -0.1660  0.026500
# 33         1  136.00  100.0  100.0  0.467  0.5230 -0.7130  0.006060
# 34         1  235.00  100.0  100.0  0.402 -0.9010  0.1640  0.005090
# 35         1  483.00  100.0  100.0  0.867  0.4500 -0.2160  0.018500
# 36         1   18.00  100.0  100.0  0.656 -0.1650 -0.7370  0.011800
# 37         1  153.00  100.0  100.0  0.866  0.1800  0.4670  0.020700
# 38         1  258.00  100.0  100.0  0.492  0.4440  0.7490  0.005950
# 39         1   33.10  100.0  100.0  0.144 -0.9060  0.3980  0.004330
# 40         1  630.00  100.0  100.0  0.921 -0.3550  0.1580  0.022600
# 41         1  558.00  100.0  100.0  0.739  0.5920  0.3200  0.015300
# 42         1   99.10  100.0  100.0  0.371  0.4190  0.8290  0.003100
# 43         1  330.00  100.0  100.0  0.547  0.1390 -0.8260  0.008780
# 44         1  530.00  100.0  100.0  0.479 -0.8570  0.1900  0.007210
# 45         1  656.00  100.0  100.0  0.552  0.7040 -0.4470  0.008600
# 46         1  403.00  100.0  100.0  0.393 -0.8840  0.2530  0.004080
# 47         0     NaN    NaN    NaN    NaN     NaN     NaN       NaN
# 48         1   13.20  100.0  100.0  0.551  0.5380 -0.6380  0.008020
# 49         1  953.00  100.0  100.0  0.755 -0.6480 -0.1000  0.016000

# %% [markdown]
# We first divert our attention the distribution of emissions.

# %%
lung_total = len(lung_df)

# %%
emissions_total = len(lung_df[lung_df["emission"] == 1])

# %%
p_emission = emissions_total/lung_total
print(f"Probability of an emission is {p_emission}.")
# Out:
# Probability of an emission is 0.9496843174129668.

# %% [markdown]
# Is there a correlation between incoming particle parameters and the presence (or not) of an emission?

# %%
stats.spearmanr(lung_df["en_p"], lung_df["emission"])
# Out:
# SpearmanrResult(correlation=-0.03854288476198962, pvalue=0.0)

# %%
stats.spearmanr(lung_df["dist_p"], lung_df["emission"])
# Out:
# SpearmanrResult(correlation=-0.32304122805746754, pvalue=0.0)

# %% [markdown]
# Notice the extremely small p-values (0 in fact), thanks to the size of our dataset. Thus we can extremely confidently reject the hypothesis that incoming energy and travelled distance are uncorrelated from emission - which makes sense.

# %% [markdown]
# Now for the correlations with the outputs:

# %%
stats.spearmanr(lung_df["de_p"], lung_df["emission"])
# Out:
# SpearmanrResult(correlation=0.3550336598908096, pvalue=0.0)

# %%
stats.spearmanr(lung_df["cos_p"], lung_df["emission"])
# Out:
# SpearmanrResult(correlation=-0.3345651545272742, pvalue=0.0)

# %% [markdown]
# Here again, no surprises that the fact an emission happened has major impact on the energy delta and the rotation of the incoming particle.

# %% [markdown]
# Let's have a look at a few other basic distributions.

# %%
sns.histplot(lung_df["en_p"].apply(np.log)).set(title="Distribution of parent particle energy in lung");

# %%
sns.histplot(lung_df["dist_p"]).set(title="Distribution of distance covered by particle before event in lung");

# %% [markdown]
# The spike at $1000$ corresponds to the step limit, i.e to the max distance a particle can cover in a step.

# %%
step_limit_df = lung_df[lung_df['dist_p'] == lung_df['dist_p'].max()]

# %%
step_limit_count = len(step_limit_df)
p_step_limit = step_limit_count/lung_total
print(f"Probability of reaching the step limit: {p_step_limit}")
# Out:
# Probability of reaching the step limit: 0.04408184711486532

# %%
emissions_when_step_limit = len(step_limit_df[step_limit_df["emission"] == 1])
p_emission_cond_step_limit = emissions_when_step_limit/step_limit_count
print(f"Probability of emission when reaching step limit (i.e P(emission | step_limit reached)): {p_emission_cond_step_limit}")
# Out:
# Probability of emission when reaching step limit (i.e P(emission | step_limit reached)): 0.006536473170748758

# %% [markdown]
# Let's understand whether the distance covered follows a power law or an exponential distribution, by looking at the plot in log-log:

# %%
sns.ecdfplot(lung_df["dist_p"], log_scale=(True,True)).set(title="ECDF of distance covered by particle before event in lung - log-log");

# %% [markdown]
# Data looks quite linear on a log-log, indicating a possible exponential distribution. Let's test that:

# %%
stats.kstest(lung_df['dist_p'], "expon")
# Out:
# KstestResult(statistic=0.9881955047506689, pvalue=0.0)

# %% [markdown]
# Test says ``dist_p`` is not exponentially distributed, interestingly. Could that be because of the lack of accuracy for small distances? (smaller than $10^{-2}$)

# %%
stats.kstest(lung_df[lung_df['dist_p'] > 0.01]['dist_p'], "expon")
# Out:
# KstestResult(statistic=0.9882128923399356, pvalue=0.0)

# %% [markdown]
# Looks like the hypothesis of an exponential distribution is to be rejected, and that the distance covered actually follows a power law.

# %% [markdown]
# Checking whether initial energy and distance travelled are correlated:

# %%
stats.spearmanr(lung_df['dist_p'], lung_df['en_p'])
# Out:
# SpearmanrResult(correlation=0.19074673903576733, pvalue=0.0)

# %% [markdown]
# They definitely are but not much. What about the emission indicator?

# %%
stats.spearmanr(lung_df['dist_p'], lung_df['emission'])
# Out:
# SpearmanrResult(correlation=-0.32304122805746754, pvalue=0.0)

# %%
for i in [0.1, 0.2, 0.3, 0.5, 1.0, 2.0, 3.0, 5.0, 10.0, 20.0]:
    p = len(lung_df[(lung_df['en_p'] == i) & (lung_df['emission'] == 1)])/len(lung_df[(lung_df['en_p'] == i)])
    print(f"For energy {i}, proba of emission: {p}")
# Out:
# For energy 0.1, proba of emission: 0.948436107645696
# For energy 0.2, proba of emission: 0.9623610566860048
# For energy 0.3, proba of emission: 0.9636030855681211
# For energy 0.5, proba of emission: 0.9600797524922654
# For energy 1.0, proba of emission: 0.9544404502808141
# For energy 2.0, proba of emission: 0.946402200245578
# For energy 3.0, proba of emission: 0.9432907523721412
# For energy 5.0, proba of emission: 0.9386179906012482
# For energy 10.0, proba of emission: 0.9349576627820034
# For energy 20.0, proba of emission: 0.9324736342280202

# %%
stats.spearmanr(lung_df['en_p'], lung_df['emission'])
# Out:
# SpearmanrResult(correlation=-0.03854288476198962, pvalue=0.0)

# %% [markdown]
# Now, let's look at the particle rotation:

# %%
sns.displot(lung_df['cos_p']).set(title="Distribution of particle rotation in lung");

# %% [markdown]
# Rotation seems roughly centered at $0$ degrees, with an additive delta at $0$ maybe due to particles that do not emit any other ones? Let's check that:

# %%
sns.displot(lung_df[lung_df['emission'] == 1]['cos_p']).set(title="Distribution of particle rotation in lung, conditioned on emission");

# %% [markdown]
# Don't forget looking at the y-axis. Indeed the spike at $0$ degree rotation has diminished, although not by that much. Let's quickly check that particles that do not emit a new one are not rotated much:

# %%
sns.histplot(lung_df[lung_df['emission'] == 0]['cos_p'], bins=400, log_scale=(False, True)).set(title="Distribution of particle rotation, conditioned on no emission");

# %%
lung_df_no_emissions = lung_df[lung_df["emission"] == 0]

# %%
len(lung_df_no_emissions[lung_df_no_emissions["cos_p"] > 0.98])/len(lung_df_no_emissions)
# Out:
# 0.9642712773776275

# %%
sns.histplot(lung_df_no_emissions["de_p"])
# Out:
# <AxesSubplot: xlabel='de_p', ylabel='Count'>

# %%
stats.spearmanr(lung_df_no_emissions["cos_p"], lung_df_no_emissions["dist_p"])
# Out:
# SpearmanrResult(correlation=0.9936766155152239, pvalue=0.0)

# %%
sns.histplot(lung_df_no_emissions["dist_p"], log_scale=(False, True));

# %%
stats.spearmanr(lung_df_no_emissions["cos_p"], lung_df_no_emissions["en_p"])
# Out:
# SpearmanrResult(correlation=0.49483956101895554, pvalue=0.0)

# %%
lung_df_emissions = lung_df[lung_df["emission"] == 1]

# %%
stats.spearmanr(lung_df_emissions["cos_p"], lung_df_emissions["dist_p"])
# Out:
# SpearmanrResult(correlation=0.06761978435435055, pvalue=0.0)

# %%
sns.histplot(lung_df_emissions["dist_p"]);

# %% [markdown]
# Now, we do similar tests for the water dataset just to check that things aren't crazily different:

# %%
water_df = pd.read_pickle("../pickled_data/water_dataset.pkl")
water_df.head(40)
# Out:
#     x_p    y_p    z_p  dx_p  dy_p  dz_p    en_p  dist_p      de_p     cos_p  \
# 0   0.0  100.0  100.0   0.1   0.0   0.0  0.0989   25.50  0.000543  0.829450
# 1   0.0  100.0  100.0   0.1   0.0   0.0  0.0951   27.30  0.000543  0.665948
# 2   0.0  100.0  100.0   0.1   0.0   0.0  0.0741   35.30  0.000029 -0.918817
# 3   0.0  100.0  100.0   0.1   0.0   0.0  0.1000   59.20  0.000000  0.790787
# 4   0.0  100.0  100.0   0.1   0.0   0.0  0.0837   61.20  0.000543 -0.911213
# 5   0.0  100.0  100.0   0.1   0.0   0.0  0.0952  139.00  0.000543  0.759469
# 6   0.0  100.0  100.0   0.1   0.0   0.0  0.0984   56.40  0.000029  0.845926
# 7   0.0  100.0  100.0   0.1   0.0   0.0  0.0693  113.00  0.000543 -0.989542
# 8   0.0  100.0  100.0   0.1   0.0   0.0  0.0871   33.70  0.000029  0.597081
# 9   0.0  100.0  100.0   0.1   0.0   0.0  0.0885  281.00  0.000029  0.328913
# 10  0.0  100.0  100.0   0.1   0.0   0.0  0.0743   51.30  0.000042 -0.709042
# 11  0.0  100.0  100.0   0.1   0.0   0.0  0.0936   30.00  0.000543  0.989237
# 12  0.0  100.0  100.0   0.1   0.0   0.0  0.0728   33.50  0.000014 -0.986753
# 13  0.0  100.0  100.0   0.1   0.0   0.0  0.0715  207.00  0.000543 -0.990303
# 14  0.0  100.0  100.0   0.1   0.0   0.0  0.0933   21.90  0.000029  0.520655
# 15  0.0  100.0  100.0   0.1   0.0   0.0  0.0826   71.90  0.000543 -0.019196
# 16  0.0  100.0  100.0   0.1   0.0   0.0  0.0897   25.90  0.000029  0.418615
# 17  0.0  100.0  100.0   0.1   0.0   0.0  0.0775   27.20  0.000014 -0.388215
# 18  0.0  100.0  100.0   0.1   0.0   0.0  0.0875  219.00  0.000042  0.249866
# 19  0.0  100.0  100.0   0.1   0.0   0.0  0.0882    2.22  0.000029  0.726496
# 20  0.0  100.0  100.0   0.1   0.0   0.0  0.0904  103.00  0.000543  0.373881
# 21  0.0  100.0  100.0   0.1   0.0   0.0  0.0887    6.19  0.000042  0.354868
# 22  0.0  100.0  100.0   0.1   0.0   0.0  0.0766   40.80  0.000543 -0.886069
# 23  0.0  100.0  100.0   0.1   0.0   0.0  0.0852   20.20  0.000042  0.080713
# 24  0.0  100.0  100.0   0.1   0.0   0.0  0.0729   15.80  0.000014 -0.785227
# 25  0.0  100.0  100.0   0.1   0.0   0.0  0.0908   60.90  0.000029  0.392862
# 26  0.0  100.0  100.0   0.1   0.0   0.0  0.0974   17.60  0.000014  0.854045
# 27  0.0  100.0  100.0   0.1   0.0   0.0  0.0719   96.20  0.000014 -0.959471
# 28  0.0  100.0  100.0   0.1   0.0   0.0  0.0778    8.83  0.000014 -0.901890
# 29  0.0  100.0  100.0   0.1   0.0   0.0  0.0776   10.70  0.000014 -0.475934
# 30  0.0  100.0  100.0   0.1   0.0   0.0  0.0000   48.10  0.000537  1.000000
# 31  0.0  100.0  100.0   0.1   0.0   0.0  0.0939  112.00  0.000029  0.999946
# 32  0.0  100.0  100.0   0.1   0.0   0.0  0.0829   74.20  0.000543 -0.804553
# 33  0.0  100.0  100.0   0.1   0.0   0.0  0.0981   34.60  0.000042  0.990802
# 34  0.0  100.0  100.0   0.1   0.0   0.0  0.0954   27.40  0.000042  0.948977
# 35  0.0  100.0  100.0   0.1   0.0   0.0  0.0827   28.60  0.000014 -0.012423
# 36  0.0  100.0  100.0   0.1   0.0   0.0  0.0729   75.50  0.000014 -0.996105
# 37  0.0  100.0  100.0   0.1   0.0   0.0  0.0871   54.30  0.000543  0.234444
# 38  0.0  100.0  100.0   0.1   0.0   0.0  0.0768    1.13  0.000014 -0.404386
# 39  0.0  100.0  100.0   0.1   0.0   0.0  0.1000   16.80  0.000000  0.997251
#
#     emission     x_c    y_c    z_c   dx_c     dy_c    dz_c      en_c
# 0          1   25.50  100.0  100.0  0.121  0.97300  0.1950  0.000553
# 1          1   27.30  100.0  100.0  0.243  0.81500 -0.5270  0.004340
# 2          1   35.30  100.0  100.0  0.991 -0.10900  0.0824  0.025900
# 3          0     NaN    NaN    NaN    NaN      NaN     NaN       NaN
# 4          1   61.20  100.0  100.0  0.968  0.22400 -0.1140  0.015800
# 5          1  139.00  100.0  100.0  0.344  0.50400  0.7920  0.004280
# 6          1   56.40  100.0  100.0  0.269 -0.96200  0.0476  0.001550
# 7          1  113.00  100.0  100.0  0.836  0.02030 -0.5480  0.030200
# 8          1   33.70  100.0  100.0  0.660 -0.20700 -0.7220  0.012900
# 9          1  281.00  100.0  100.0  0.586 -0.51500  0.6250  0.011500
# 10         1   51.30  100.0  100.0  0.955 -0.26800  0.1240  0.025700
# 11         1   30.00  100.0  100.0  0.486  0.15500 -0.8600  0.005900
# 12         1   33.50  100.0  100.0  0.987  0.03230  0.1560  0.027200
# 13         1  207.00  100.0  100.0  0.909  0.03320  0.4160  0.027900
# 14         1   21.90  100.0  100.0  0.522  0.85300 -0.0143  0.006620
# 15         1   71.90  100.0  100.0  0.813 -0.45800 -0.3590  0.016900
# 16         1   25.90  100.0  100.0  0.617 -0.55400  0.5600  0.010300
# 17         1   27.20  100.0  100.0  0.896  0.40500 -0.1810  0.022500
# 18         1  219.00  100.0  100.0  0.663 -0.70700  0.2460  0.012500
# 19         1    2.22  100.0  100.0  0.656 -0.16500 -0.7370  0.011800
# 20         1  103.00  100.0  100.0  0.564  0.18600 -0.8050  0.009070
# 21         1    6.19  100.0  100.0  0.690  0.52800  0.4960  0.011300
# 22         1   40.80  100.0  100.0  0.981  0.12500 -0.1490  0.022800
# 23         1   20.20  100.0  100.0  0.754  0.64700 -0.1150  0.014700
# 24         1   15.80  100.0  100.0  0.972  0.22600 -0.0613  0.027100
# 25         1   60.90  100.0  100.0  0.560  0.71600  0.4170  0.009160
# 26         1   17.60  100.0  100.0  0.223  0.71500 -0.6630  0.002620
# 27         1   96.20  100.0  100.0  0.991  0.11400 -0.0765  0.028100
# 28         1    8.83  100.0  100.0  0.881  0.09530  0.4630  0.022200
# 29         1   10.70  100.0  100.0  0.903 -0.35900  0.2370  0.022400
# 30         1   48.10  100.0  100.0  0.700  0.07910 -0.7100  0.099500
# 31         1  112.00  100.0  100.0  0.468 -0.00560  0.8840  0.006110
# 32         1   74.20  100.0  100.0  0.925  0.02390 -0.3800  0.016600
# 33         1   34.60  100.0  100.0  0.275  0.21500  0.9370  0.001840
# 34         1   27.40  100.0  100.0  0.419 -0.21400  0.8820  0.004600
# 35         1   28.60  100.0  100.0  0.760  0.64700 -0.0578  0.017300
# 36         1   75.50  100.0  100.0  0.990 -0.00918 -0.1400  0.027100
# 37         1   54.30  100.0  100.0  0.650  0.71400  0.2600  0.012300
# 38         1    1.13  100.0  100.0  0.919 -0.39000  0.0531  0.023200
# 39         0     NaN    NaN    NaN    NaN      NaN     NaN       NaN

# %%
len(water_df)
# Out:
# 8818755

# %%
sns.histplot(lung_df["en_p"]).set(title="Distribution of parent particle energy in water");

# %% [markdown]
# Nothing changed much there.

# %%
sns.histplot(water_df["dist_p"]).set(title="Distribution of distance covered by particle in water");

# %% [markdown]
# Interestingly, much less particles reach the step limit.

# %%
step_limit_df = water_df[water_df['dist_p'] == water_df['dist_p'].max()]

# %%
step_limit_count = len(step_limit_df)
p_step_limit = step_limit_count/len(water_df)
print(f"Probability of reaching the step limit: {p_step_limit}")
# Out:
# Probability of reaching the step limit: 0.0006067749926151708

# %% [markdown]
# Can this have anything do with the probability of emission?

# %%
emission_count = len(water_df[water_df["emission"] == 1])
p_emission = emission_count/len(water_df)
print(f"Probability of emission: {p_emission}")
# Out:
# Probability of emission: 0.9936640716291585

# %% [markdown]
# In this indeed much higher than in the lung. Lastly, for the correlation between energy and distance, which was noticeably low for the lungs:

# %%
stats.spearmanr(water_df['dist_p'], water_df['en_p'])
# Out:
# SpearmanrResult(correlation=0.3321852443114158, pvalue=0.0)

# %% [markdown]
# It's a bit higher here. We expect quite different models, although a very similar ML system architecture can still be used for both datasets.

# %% [markdown]
# About augmented data:

# %%
# %%time
lung_aug_df = pd.read_pickle("../pickled_data/lung_augmented_dataset.pkl")
# Out:
# CPU times: total: 7.03 s
# Wall time: 1min 21s

# %%
sns.histplot(lung_aug_df["en_p"]).set(title="Energy distribution in augmented data");
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [51], line 1
# ----> 1 sns.histplot(lung_aug_df["en_p"]).set(title="Energy distribution in augmented data");
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
#    1436         shrink=shrink,
#    1437         common_norm=common_norm,
#    1438         common_bins=common_bins,
#    1439         kde=kde,
#    1440         kde_kws=kde_kws,
#    1441         color=color,
#    1442         legend=legend,
#    1443         estimate_kws=estimate_kws,
#    1444         line_kws=line_kws,
#    1445         **kwargs,
#    1446     )
#    1448 else:
#    1450     p.plot_bivariate_histogram(
#    1451         common_bins=common_bins,
#    1452         common_norm=common_norm,
#    (...)
#    1462         **kwargs,
#    1463     )
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\seaborn\distributions.py:430, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     427 histograms = {}
#     429 # Do pre-compute housekeeping related to multiple groups
# --> 430 all_data = self.comp_data.dropna()
#     431 all_weights = all_data.get("weights", None)
#     433 multiple_histograms = set(self.variables) - {"x", "y"}
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\seaborn\_oldcore.py:1120, in VectorPlotter.comp_data(self)
#    1118 for converter, orig in grouped:
#    1119     with pd.option_context('mode.use_inf_as_null', True):
# -> 1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#    1125             orig = orig[orig.isin(self.var_levels[var])]
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\series.py:5823, in Series.dropna(self, axis, inplace, how)
#    5820 self._get_axis_number(axis or 0)
#    5822 if self._can_hold_na:
# -> 5823     result = remove_na_arraylike(self)
#    5824     if inplace:
#    5825         self._update_inplace(result)
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\dtypes\missing.py:692, in remove_na_arraylike(arr)
#     690     return arr[notna(arr)]
#     691 else:
# --> 692     return arr[notna(np.asarray(arr))]
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\series.py:1005, in Series.__getitem__(self, key)
#    1003     key = check_bool_indexer(self.index, key)
#    1004     key = np.asarray(key, dtype=bool)
# -> 1005     return self._get_values(key)
#    1007 return self._get_with(key)
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\series.py:1069, in Series._get_values(self, indexer)
#    1068 def _get_values(self, indexer: slice | npt.NDArray[np.bool_]) -> Series:
# -> 1069     new_mgr = self._mgr.getitem_mgr(indexer)
#    1070     return self._constructor(new_mgr).__finalize__(self)
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\internals\managers.py:2004, in SingleBlockManager.getitem_mgr(self, indexer)
#    2001 bp = BlockPlacement(slice(0, len(array)))
#    2002 block = type(blk)(array, placement=bp, ndim=1)
# -> 2004 new_idx = self.index[indexer]
#    2005 # TODO(CoW) in theory only need to track reference if new_array is a view
#    2006 ref = weakref.ref(blk)
#
# File D:\EPFL cours\DS MA\ML MA1\MLprojects\venv\lib\site-packages\pandas\core\indexes\base.py:5380, in Index.__getitem__(self, key)
#    5377     else:
#    5378         key = np.asarray(key, dtype=bool)
# -> 5380 result = getitem(key)
#    5381 # Because we ruled out integer above, we always get an arraylike here
#    5382 if result.ndim > 1:
#
# MemoryError: Unable to allocate 463. MiB for an array with shape (60726958,) and data type int64
